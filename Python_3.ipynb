# %%
# Siempre, lo primero que debo hacer es importar Pandas y Numpy
import pandas as pd
import numpy as np

# %%
#Ahora subimos el archivo desde google drive sin looguearnos
df_estudiantes=pd.read_csv("/content/drive/MyDrive/StudentsPerformance (1).csv")
df_estudiantes
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#Sigamos con la creación de columnas usando el método assign o el método insert
#Si quiero agregar varias columnas uso assign y también si quiero sobreescribir una columna
filosofia_score=np.random.randint(0,100, size=1000)
fisica_score=np.random.randint(0,100, size=1000)

# %%
#Ahora le pondré un indíce a cada fila para que sepa donde va en el DataFrame
filosofia_nota=pd.Series(filosofia_score, index=np.arange(0,1000))
fisica_nota=pd.Series(fisica_score, index=np.arange(0,1000))

# %%
#Ahora lo que voy a hacer es poner las nuevas columnas a mi DataFrame, usando asing
df_estudiantes.assign(filosofia_score=filosofia_nota, fisica_score=fisica_nota)
df_estudiantes
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_estudiantes=df_estudiantes.assign(filosofia_score=filosofia_nota, fisica_score=fisica_nota)
df_estudiantes
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#Para usar el método insert este no me devuelve copias sino que el cambio queda guardado de inmediato
df_estudiantes.insert(1,"Ed. Score", fisica_nota)
df_estudiantes
# Out:
#      gender  Ed. Score race/ethnicity parental level of education  \
# 0    female         86        group B           bachelor's degree
# 1    female         94        group C                some college
# 2    female          1        group B             master's degree
# 3      male         15        group A          associate's degree
# 4      male         80        group C                some college
# ..      ...        ...            ...                         ...
# 995  female         98        group E             master's degree
# 996    male         80        group C                 high school
# 997  female          1        group C                 high school
# 998  female         61        group D                some college
# 999  female         11        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none          72             72
# ...
