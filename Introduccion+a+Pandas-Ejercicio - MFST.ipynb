# %%
# importar pandas
import pandas as pd

# %%
# Opcional: usa el pd.set_option() para mostrar todas las filas de un dataframe por defecto

# %% [markdown]
# # Crear un DataFrame

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# leer el archivo csv "bestsellers with categories" (data sobre los 50 libros más vendidos de Amazon de 2009 a 2019.)
df_Best_Seller=pd.read_csv("/content/drive/MyDrive/python/bestsellers+with+categories - bestsellers+with+categories.csv")
df_Best_Seller
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %%
# acceder al atributo shape
print(df_Best_Seller.shape)
# Out:
# (550, 7)

# %%
# encontrar el tipo de data de cada columna
df_Best_Seller.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %% [markdown]
# # Mostrar un DataFrame

# %%
# mostrar primeras 5 filas de un dataframe
df_Best_Seller.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# encontrar valores estadisticos de un dataframe (mean, std, min, max)
import numpy as np
Promedio=df_Best_Seller["Price"].mean()
Desviación_estándar=df_Best_Seller["Price"].std()
Mínimo=df_Best_Seller["Price"].min()
Máximo=df_Best_Seller["Price"].max()
print(Promedio)
print(Desviación_estándar)
print(Mínimo)
print(Máximo)
# Out:
# 13.1
# 10.84226197842238
# 0
# 105

# %% [markdown]
# # Agregar una nueva Columna

# %%
# Tu tarea es crear una columna llamada 'Critic Rating' que deberia tener numeros random enteros entre 1 y 4
# 1.importar numpy y crear 550 numeros random enteros entre 1 y 4
import numpy as np
Critic_rating=np.random.randint(1,4, size=550)
# 2.agregar nueva columna 'Critic Rating' al dataframe usando los numeros random creados
Critic_score=pd.Series(Critic_rating, index=np.arange(0,550))
df_Best_Seller=df_Best_Seller.assign(Critic_rating=Critic_score)
df_Best_Seller
# Obs: Los numeros aleatorios en la columna 'Critic Rating' seran diferentes entre tu solucion y la mia, pero vamos a concetrarnos en el codigo en esta seccion.
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
#      Critic_rating
# 0                2
# 1                2
# 2                1
# 3                2
# 4                3
# ..             ...
# 545              2
# 546              3
# 547              2
# 548              1
# 549              1
#
# [550 rows x 8 columns]

# %%
# mostrar 5 primeras filas
df_Best_Seller.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    Critic_rating
# 0              2
# 1              2
# 2              1
# 3              2
# 4              3

# %% [markdown]
# # Atributos, Metodos y Funciones Basicas

# %%
# acceder al atributo "columns"
print(df_Best_Seller.columns)
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre',
#        'Critic_rating'],
#       dtype='object')

# %% [markdown]
# # Seleccionar 2 o Mas Columnas de un Dataframe

# %%
# mover la columna 'Critic Rating' entre las columnas "User Rating" y "Reviews" Luego actualizar el dataframe
Critic_rating=np.random.randint(1,4, size=550)
Critic_score=pd.Series(Critic_rating, index=np.arange(0,550))
df_Best_Seller["Critic_rating"]
df_Best_Seller
# Tip: Copiar y pegar los nombres de columna obtenidos con el atributo "columns" y reordenar los elementos usando [[]]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
#      Critic_rating
# 0                2
# 1                2
# 2                1
# 3                2
# 4                3
# ..             ...
# 545              2
# 546              3
# 547              2
# 548              1
# 549              1
#
# [550 rows x 8 columns]

# %%
# mostrar 5 primeras filas
df_Best_Seller.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    Critic_rating
# 0              2
# 1              2
# 2              1
# 3              2
# 4              3

# %% [markdown]
# # Operaciones en Dataframes

# %%
# crear una columna llamada "Average Rating" usando la sigueinte formula: Average Rating = (User Rating + Critic Rating)/2
df_Best_Seller["Average rating"]=((df_Best_Seller["User Rating"]+df_Best_Seller["Critic_rating"])/2)
df_Best_Seller
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
#      Critic_rating  Average rating
# 0                2            3.35
# 1                2            3.30
# 2                1            2.85
# 3                2            3.35
# 4                3            3.90
# ..             ...             ...
# 545              2            3.45
# 546              3            3.85
# 547              2            3.35
# 548              1            2.85
# 549              1            2.85
#
# [550 rows x 9 columns]

# %%
# usar la funcion "round" para redondear los valores del dataframe a 1 decimal y actualizar el dataframe
df_Best_Seller["Average rating"]=df_Best_Seller["Average rating"].round(1)
df_Best_Seller
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
#      Critic_rating  Average rating
# 0                2             3.4
# 1                2             3.3
# 2                1             2.8
# 3                2             3.4
# 4                3             3.9
# ..             ...             ...
# 545              2             3.4
# 546              3             3.8
# 547              2             3.4
# 548              1             2.8
# 549              1             2.8
#
# [550 rows x 9 columns]

# %% [markdown]
# # Contar Valores

# %%
# contar elementos en columna "Genre" por categoria y devolver la frecuencia relativa
df_Best_Seller["Genre"].value_counts()
# Out:
# Genre
# Non Fiction    310
# Fiction        240
# Name: count, dtype: int64

# %% [markdown]
# # Renombrar Columnas

# %%
# renombrar columnas "User Rating," "Critic Rating" y "Average Rating" a "UR," "CR" y "AR" Luego actualizar el dataframe con el parametro "inplace"
df_Best_Seller=df_Best_Seller.rename(columns={'User Rating': 'UR',
                                             'Critic_rating': 'CR',
                                             'Average rating': 'AR'})
df_Best_Seller
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author   UR  Reviews  Price  Year        Genre  CR   AR
# 0                    JJ Smith  4.7    17350      8  2016  Non Fiction   2  3.4
# 1                Stephen King  4.6     2052     22  2011      Fiction   2  3.3
# 2          Jordan B. Peterson  4.7    18979     15  2018  Non Fiction   1  2.8
# 3               George Orwell  4.7    21424      6  2017      Fiction   2  3.4
# 4    National Geographic Kids  4.8     7665     12  2019  Non Fiction   3  3.9
# ..                        ...  ...      ...    ...   ...          ...  ..  ...
# 545               Jeff Kinney  4.9     9413      8  2019      Fiction   2  3.4
# 546               Jen Sincero  4.7    14331      8  2016  Non Fiction   3  3.8
# 547               Jen Sincero  4.7    14331      8  2017  Non Fiction   2  3.4
# 548               Jen Sincero  4.7    14331      8  2018  Non Fiction   1  2.8
# 549               Jen Sincero  4.7    14331      8  2019  Non Fiction   1  2.8
#
# [550 rows x 9 columns]

# %%
# mostrar 5 primeras filas
df_Best_Seller.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author   UR  Reviews  Price  Year        Genre  CR   AR
# 0                  JJ Smith  4.7    17350      8  2016  Non Fiction   2  3.4
# 1              Stephen King  4.6     2052     22  2011      Fiction   2  3.3
# 2        Jordan B. Peterson  4.7    18979     15  2018  Non Fiction   1  2.8
# 3             George Orwell  4.7    21424      6  2017      Fiction   2  3.4
# 4  National Geographic Kids  4.8     7665     12  2019  Non Fiction   3  3.9

# %%
# seleccionar solo columnas "Name", "Author", "UR", "CR", "AR" y "Year" y actualizar el dataframe
df_Best_Seller=df_Best_Seller[["Name","Author","UR","CR","AR","Year"]]
df_Best_Seller
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author   UR  CR   AR  Year
# 0                    JJ Smith  4.7   2  3.4  2016
# 1                Stephen King  4.6   2  3.3  2011
# 2          Jordan B. Peterson  4.7   1  2.8  2018
# 3               George Orwell  4.7   2  3.4  2017
# 4    National Geographic Kids  4.8   3  3.9  2019
# ..                        ...  ...  ..  ...   ...
# 545               Jeff Kinney  4.9   2  3.4  2019
# 546               Jen Sincero  4.7   3  3.8  2016
# 547               Jen Sincero  4.7   2  3.4  2017
# 548               Jen Sincero  4.7   1  2.8  2018
# 549               Jen Sincero  4.7   1  2.8  2019
#
# [550 rows x 6 columns]

# %% [markdown]
# # Ordenar el dataframe

# %%
# ordenar el dataframe en forma descendente segun las columnas "UR" y "CR"
df_Best_Seller=df_Best_Seller.sort_values(["UR","CR"], ascending=False)
df_Best_Seller
# Out:
#                                                   Name                Author  \
# 81   Dog Man and Cat Kid: From the Creator of Capta...            Dav Pilkey
# 83   Dog Man: Brawl of the Wild: From the Creator o...            Dav Pilkey
# 147  Goodnight, Goodnight Construction Site (Hardco...  Sherri Duskey Rinker
# 151                           Hamilton: The Revolution    Lin-Manuel Miranda
# 174                       Humans of New York : Stories       Brandon Stanton
# ..                                                 ...                   ...
# 393  The Goldfinch: A Novel (Pulitzer Prize for Fic...           Donna Tartt
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...             E L James
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...             E L James
# 132                         Go Set a Watchman: A Novel            Harper Lee
# 353                                 The Casual Vacancy          J.K. Rowling
#
#       UR  CR   AR  Year
# 81   4.9   3  4.0  2018
# 83   4.9   3  4.0  2018
# 147  4.9   3  4.0  2013
# 151  4.9   3  4.0  2016
# 174  4.9   3  4.0  2015
# ..   ...  ..  ...   ...
# 393  3.9   1  2.4  2014
# 106  3.8   3  3.4  2012
# 107  3.8   2  2.9  2013
# 132  3.6   3  3.3  2015
# 353  3.3   1  2.2  2012
#
# [550 rows x 6 columns]
